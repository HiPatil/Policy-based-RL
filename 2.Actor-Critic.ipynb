# %% [markdown]
# # Action Value Actor Critic (QAC)

# %%
import numpy as np
import time
import random
import gym

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import matplotlib.pyplot as plt

from IPython.display import clear_output
# %matplotlib inline

# %%
env = gym.make('InvertedPendulum-v2')

print('Observation Shape:', env.observation_space.shape, '\nAction Shape:', env.action_space)
# env.reset()
# for _ in range(100):
#     env.render()
#     time.sleep(0.01)
#     env.step(env.action_space.sample())   # take random actions  
# env.close()
# Out:
# Observation Shape: (4,)
# Action Shape: Box(1,)

# %% [markdown]
# ### Checking for cuda device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### Initialization of Hyperparameters

# %%
LEARNING_RATE = 0.001
DISCOUNT = 0.99
EPS = 1
EPS_DECAY = 0.9999
END_EPS = 0.1

N_EPISODE = 1500


# Dimensions of input and output of environment
obs_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
print(action_dim)
# Out:
# 1

# %% [markdown]
# ### Actor Network

# %%
class Actor(nn.Module):
    def __init__(self, observations, actions):
        super(Actor, self).__init__()
        self.actor = nn.Sequential(
            nn.Linear(observations, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU()
        )
        self.l1 = nn.Linear(16, actions)
        self.l2 = nn.Linear(16, actions)
        
    def forward(self, x):
        x = self.actor(x)
        mean = self.l1(x)
        variance = F.softplus(self.l2(x))
        
        return mean, variance

# %%
actor = Actor(obs_dim, action_dim).to(device)
optimizerA = optim.Adam(actor.parameters(), lr = LEARNING_RATE)

# %% [markdown]
# ### Sampling of action from Normal Distribution

# %%
def actors_action(state):
    
    mean, variance = actor(state)
    
    dist = torch.distributions.Normal(mean, torch.sqrt(variance))
    action = dist.sample()
    log_prob = dist.log_prob(action).sum(-1).unsqueeze(-1)
    
    return action.detach().cpu().numpy(), log_prob

# %% [markdown]
# ### Critic Network

# %%
class Critic(nn.Module):
    def __init__(self, observations):
        super(Critic, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(observations, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )
    
    def forward(self, x):
        return self.network(x)

# %%
critic = Critic(obs_dim).to(device)
optimizerC = optim.Adam(critic.parameters(), lr = LEARNING_RATE)
criterionC = nn.MSELoss().to(device)

# %% [markdown]
# ### Computing Q-Values

# %%
def compute_returns(next_state, rewards, done, discount = DISCOUNT):
#     q_val = critic(state)

    next_state = torch.FloatTensor(next_state).to(device)
    next_q_val = critic(next_state)
    returns = []
    
    for step in reversed(range(len(rewards))):
        next_q_val = rewards[step] + discount*next_q_val*(1-done[step])
        returns.append(next_q_val)
        
    returns.reverse()
    return returns

# %% [markdown]
# ### Updating Actor based on Q-values by critic

# %%
def ACupdate(log_probs, ret, values):
    optimizerA.zero_grad()
    optimizerC.zero_grad()
    
    actor_loss = 0
    critic_loss = 0

    for log_prob, value, retr in zip(log_probs, values, ret):
                
        actor_loss -= log_prob*retr
#         print('AL', actor_loss)
        
#         print(criterionC(value, retr))
        critic_loss += criterionC(retr.detach(), value)
        
    actor_loss.backward()
    critic_loss.backward()
    
    optimizerA.step()
    optimizerC.step()
    
    return (actor_loss+critic_loss).item()

# %%
mean_avg = []

def plot(n_rewards, loss):
    clear_output(True)
    plt.figure(figsize=(30,6))
    mean = np.mean(n_rewards[-10:])
    plt.subplot(131)
    mean_avg.append(mean)
    plt.title('Reward: %s' % (mean))
    plt.plot(n_rewards)
    plt.plot(mean_avg)
    
    l = loss[-1]
    plt.subplot(132)
    plt.title('loss %.2f' %l)
    plt.plot(loss)
    plt.show()

# %% [markdown]
# ### Training QAC

# %%
n_rewards = []
losses = []

for i in range(1, N_EPISODE+1):
    ep_rewards = []
    log_probs = []
    done_states = []
#     returns = []
    total_reward = 0
    done = False
    values = []
    
    state = env.reset()
    ret = 0
    
    while not done:
        state = torch.FloatTensor(state).to(device)
        action, log_prob = actors_action(state)
        
        value = critic(state)
        next_state, reward, done, _ = env.step(action)
        
        
        done = torch.tensor([done], dtype = torch.float, device = device)
        
        ep_rewards.append(torch.tensor([reward], dtype = torch.float, device = device))
        log_probs.append(log_prob)
        done_states.append(done)
        values.append(value)

        total_reward += reward
#         ret = compute_returns(next_state, reward, done, ret)
#         if i%5 == 0:
#             env.render()
        state = next_state
        
    q_vals = compute_returns(next_state, ep_rewards, done_states)
    
    loss = ACupdate(log_probs, q_vals, values)
    
    n_rewards.append(total_reward)
    losses.append(loss)
    plot(n_rewards, losses)
    
    if np.mean(n_rewards[-10:]) == 1000:
        torch.save(actor.state_dict(), 'actor.pth')
        torch.save(critic.state_dict(), 'critic.pth')
        print("Model Saved")

# %%
state = env.reset()


total_reward = 0
done = False

actor.load_state_dict(torch.load('/home/himanshu/1.RL/Policy-based-RL/actor.pth'))
critic.load_state_dict(torch.load('/home/himanshu/1.RL/Policy-based-RL/critic.pth'))
print("Model Loaded")
actor.to(device)
critic.to(device)

while not done:
    state = torch.FloatTensor(state).to(device)
    action, log_prob = actors_action(state)
    
    next_state, reward, done, _ = env.step(action)
    total_reward += reward
    
    env.render()
    time.sleep(0.01)
    
    state = next_state
    
print('Duration till which pole is balanced: ', total_reward)

env.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-d6efef3b3f00> in <module>
#       5 done = False
#       6
# ----> 7 actor.load_state_dict(torch.load('/home/himanshu/1.RL/Policy-based-RL/actor.pth'))
#       8 critic.load_state_dict(torch.load('/home/himanshu/1.RL/Policy-based-RL/critic.pth'))
#       9 print("Model Loaded")
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     582         pickle_load_args['encoding'] = 'utf-8'
#     583
# --> 584     with _open_file_like(f, 'rb') as opened_file:
#     585         if _is_zipfile(opened_file):
#     586             with _open_zipfile_reader(f) as opened_zipfile:
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     232 def _open_file_like(name_or_buffer, mode):
#     233     if _is_path(name_or_buffer):
# --> 234         return _open_file(name_or_buffer, mode)
#     235     else:
#     236         if 'w' in mode:
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/torch/serialization.py in __init__(self, name, mode)
#     213 class _open_file(_opener):
#     214     def __init__(self, name, mode):
# --> 215         super(_open_file, self).__init__(open(name, mode))
#     216
#     217     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/himanshu/1.RL/Policy-based-RL/actor.pth'
